# %% [markdown]
# <a href="https://colab.research.google.com/github/BahodirML/Coding_Practices/blob/main/COMPANY_ACQUISITION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#labelling
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('/content/companies.csv')
df.head()
# Out:
#         id  Unnamed: 0.1 entity_type  entity_id  parent_id  \
# 0      c:1             0     Company          1        NaN
# 1     c:10             1     Company         10        NaN
# 2    c:100             2     Company        100        NaN
# 3  c:10000             3     Company      10000        NaN
# 4  c:10001             4     Company      10001        NaN
#
#                  name     normalized_name                    permalink  \
# 0            Wetpaint            wetpaint            /company/wetpaint
# 1             Flektor             flektor             /company/flektor
# 2               There               there               /company/there
# 3             MYWEBBO             mywebbo             /company/mywebbo
# 4  THE Movie Streamer  the movie streamer  /company/the-movie-streamer
#
#      category_code     status  ... first_milestone_at last_milestone_at  \
# 0              web  operating  ...         2010-09-05        2013-09-18
# 1      games_video   acquired  ...                NaN               NaN
# 2      games_video   acquired  ...         2003-02-01        2011-09-23
# 3  network_hosting  operating  ...                NaN               NaN
# 4      games_video  operating  ...                NaN               NaN
#
#   milestones relationships        created_by           created_at  \
# 0        5.0          17.0  initial-importer  2007-05-25 06:51:27
# 1        NaN           6.0  initial-importer  2007-05-31 21:11:51
# 2        4.0          12.0  initial-importer  2007-08-06 23:52:45
# 3        NaN           NaN               NaN  2008-08-24 16:51:57
# 4        NaN           NaN               NaN  2008-08-24 17:10:34
#
#             updated_at        lat         lng   ROI
# 0  2013-04-13 03:29:00  47.606209 -122.332071  15.5
# 1  2008-05-23 23:23:14  34.021122 -118.396467   NaN
# 2  2013-11-04 02:09:48  37.562992 -122.325525   NaN
# 3  2008-09-06 14:19:18        NaN         NaN   NaN
# 4  2008-09-06 14:19:18        NaN         NaN   NaN
#
# [5 rows x 44 columns]

# %%
df.shape
# Out:
# (196553, 44)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196553 entries, 0 to 196552
# Data columns (total 44 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   196553 non-null  object
#  1   Unnamed: 0.1         196553 non-null  int64
#  2   entity_type          196553 non-null  object
#  3   entity_id            196553 non-null  int64
#  4   parent_id            0 non-null       float64
#  5   name                 196531 non-null  object
#  6   normalized_name      196527 non-null  object
#  7   permalink            196553 non-null  object
#  8   category_code        123186 non-null  object
#  9   status               196553 non-null  object
#  10  founded_at           91227 non-null   object
#  11  closed_at            2620 non-null    object
#  12  domain               126545 non-null  object
#  13  homepage_url         126545 non-null  object
#  14  twitter_username     80591 non-null   object
#  15  logo_url             110110 non-null  object
#  16  logo_width           110110 non-null  float64
#  17  logo_height          110110 non-null  float64
#  18  short_description    7131 non-null    object
#  19  description          92048 non-null   object
#  20  overview             126971 non-null  object
#  21  tag_list             81452 non-null   object
#  22  country_code         87990 non-null   object
#  23  state_code           50903 non-null   object
#  24  city                 83890 non-null   object
#  25  region               196553 non-null  object
#  26  first_investment_at  2583 non-null    object
#  27  last_investment_at   2583 non-null    object
#  28  investment_rounds    2591 non-null    float64
#  29  invested_companies   2591 non-null    float64
#  30  first_funding_at     31507 non-null   object
#  31  last_funding_at      31507 non-null   object
#  32  funding_rounds       31707 non-null   float64
#  33  funding_total_usd    27874 non-null   float64
#  34  first_milestone_at   91699 non-null   object
#  35  last_milestone_at    91699 non-null   object
#  36  milestones           91699 non-null   float64
#  37  relationships        129667 non-null  float64
#  38  created_by           155533 non-null  object
#  39  created_at           196553 non-null  object
#  40  updated_at           196553 non-null  object
#  41  lat                  83852 non-null   float64
#  42  lng                  83852 non-null   float64
#  43  ROI                  726 non-null     float64
# dtypes: float64(12), int64(2), object(30)
# memory usage: 66.0+ MB

# %%
df.dtypes
# Out:
# id                      object
# Unnamed: 0.1             int64
# entity_type             object
# entity_id                int64
# parent_id              float64
# name                    object
# normalized_name         object
# permalink               object
# category_code           object
# status                  object
# founded_at              object
# closed_at               object
# domain                  object
# homepage_url            object
# twitter_username        object
# logo_url                object
# logo_width             float64
# logo_height            float64
# short_description       object
# description             object
# overview                object
# tag_list                object
# country_code            object
# state_code              object
# city                    object
# region                  object
# first_investment_at     object
# last_investment_at      object
# investment_rounds      float64
# invested_companies     float64
# first_funding_at        object
# last_funding_at         object
# funding_rounds         float64
# funding_total_usd      float64
# first_milestone_at      object
# last_milestone_at       object
# milestones             float64
# relationships          float64
# created_by              object
# created_at              object
# updated_at              object
# lat                    float64
# lng                    float64
# ROI                    float64
# dtype: object

# %%
df.describe()
# Out:
#         Unnamed: 0.1      entity_id  parent_id     logo_width    logo_height  \
# count  196553.000000  196553.000000        0.0  110110.000000  110110.000000
# mean    98276.000000  153006.227333        NaN     459.132685     222.728917
# std     56740.108067   90209.250941        NaN     594.982577     333.090722
# min         0.000000       1.000000        NaN       1.000000       1.000000
# 25%     49138.000000   59850.000000        NaN     192.000000      70.000000
# 50%     98276.000000  174539.000000        NaN     267.000000     105.000000
# 75%    147414.000000  232655.000000        NaN     484.000000     232.000000
# max    196552.000000  286215.000000        NaN   18200.000000    9600.000000
#
#        investment_rounds  invested_companies  funding_rounds  \
# count        2591.000000         2591.000000    31707.000000
# mean            2.372057            2.204940        1.659760
# std            12.173510           11.436955        1.201666
# min             1.000000            1.000000        1.000000
# 25%             1.000000            1.000000        1.000000
# 50%             1.000000            1.000000        1.000000
# 75%             1.000000            1.000000        2.000000
# max           478.000000          459.000000       15.000000
#
#        funding_total_usd    milestones  relationships           lat  \
# count       2.787400e+04  91699.000000  129667.000000  83852.000000
# mean        1.481652e+07      1.199402       2.852067     37.564512
# std         6.775937e+07      0.540099       9.100309     15.477102
# min         2.910000e+02      1.000000       1.000000    -50.942326
# 25%         5.000000e+05      1.000000       1.000000     34.052234
# 50%         2.564500e+06      1.000000       1.000000     39.768403
# 75%         1.100000e+07      1.000000       3.000000     45.421530
# max         5.700000e+09      9.000000    1189.000000     77.553604
#
#                 lng           ROI
# count  83852.000000    726.000000
# mean     -52.123066     45.745037
# std       70.049067    572.035638
# min     -159.497746      0.011111
# 25%     -111.940005      2.648879
# 50%      -77.036871      6.500497
# 75%       -0.127758     13.549900
# max      176.212549  13333.333333

# %%
df.isnull().sum()
# Out:
# id                          0
# Unnamed: 0.1                0
# entity_type                 0
# entity_id                   0
# parent_id              196553
# name                       22
# normalized_name            26
# permalink                   0
# category_code           73367
# status                      0
# founded_at             105326
# closed_at              193933
# domain                  70008
# homepage_url            70008
# twitter_username       115962
# logo_url                86443
# logo_width              86443
# logo_height             86443
# short_description      189422
# description            104505
# overview                69582
# tag_list               115101
# country_code           108563
# state_code             145650
# city                   112663
# region                      0
# first_investment_at    193970
# last_investment_at     193970
# investment_rounds      193962
# invested_companies     193962
# first_funding_at       165046
# last_funding_at        165046
# funding_rounds         164846
# funding_total_usd      168679
# first_milestone_at     104854
# last_milestone_at      104854
# milestones             104854
# relationships           66886
# created_by              41020
# created_at                  0
# updated_at                  0
# lat                    112701
# lng                    112701
# ROI                    195827
# dtype: int64

# %%
# Dropping unnecessary columns
df.drop(['Unnamed: 0.1','entity_type','entity_id','parent_id','twitter_username','logo_url','short_description','description',
        'first_investment_at','closed_at','last_investment_at','investment_rounds','invested_companies'],axis=1,inplace=True)

# %%
# Filling the missing values of datetime type columns using ffill
date_columns = ['founded_at','first_funding_at','last_funding_at','first_milestone_at','last_milestone_at']

for i in date_columns:
    df[i].fillna(method='ffill',inplace = True)

# %%
# Filling the missing values in categorical columns with the value: 'Unavailable'
cat_columns = ['domain','homepage_url','overview','tag_list','name','normalized_name']

for x in cat_columns:
    df[x].fillna('Unavailable',inplace = True)

# %%
# Filling the missing values in the categorical columns with their respective mode values
cat_columns2 = ['category_code','country_code','state_code','city','created_by']

for i in cat_columns2:
    mode_val = df[i].mode()[0]
    df[i].fillna(mode_val,inplace = True)

# %%
# Filling the missing values in the latitude and longitude columns
df['lng'] = df['lng'].interpolate(method='linear')
df['lat'] = df['lat'].interpolate(method ='linear')

# %%
# Filling the missing values in numeric columns with their respective mean values
num_columns = ['logo_width','logo_height','funding_rounds','funding_total_usd','milestones','relationships','ROI']

for i in num_columns:
    df[i].fillna(df[i].mean(),inplace = True)

# %%
df.isnull().sum()
# Out:
# id                    0
# name                  0
# normalized_name       0
# permalink             0
# category_code         0
# status                0
# founded_at            0
# domain                0
# homepage_url          0
# logo_width            0
# logo_height           0
# overview              0
# tag_list              0
# country_code          0
# state_code            0
# city                  0
# region                0
# first_funding_at      0
# last_funding_at       0
# funding_rounds        0
# funding_total_usd     0
# first_milestone_at    0
# last_milestone_at     0
# milestones            0
# relationships         0
# created_by            0
# created_at            0
# updated_at            0
# lat                   0
# lng                   0
# ROI                   0
# dtype: int64

# %%
# Changing the datatype of date columns from object to datetime type

df['founded_at'] = pd.to_datetime(df['founded_at'])
df['first_funding_at'] = pd.to_datetime(df['first_funding_at'])
df['last_funding_at'] = pd.to_datetime(df['last_funding_at'])
df['first_milestone_at'] = pd.to_datetime(df['first_milestone_at'])
df['last_milestone_at'] = pd.to_datetime(df['last_milestone_at'])
df['created_at'] = pd.to_datetime(df['created_at'])
df['updated_at'] = pd.to_datetime(df['updated_at'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196553 entries, 0 to 196552
# Data columns (total 31 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  196553 non-null  object
#  1   name                196553 non-null  object
#  2   normalized_name     196553 non-null  object
#  3   permalink           196553 non-null  object
#  4   category_code       196553 non-null  object
#  5   status              196553 non-null  object
#  6   founded_at          196553 non-null  datetime64[ns]
#  7   domain              196553 non-null  object
#  8   homepage_url        196553 non-null  object
#  9   logo_width          196553 non-null  float64
#  10  logo_height         196553 non-null  float64
#  11  overview            196553 non-null  object
#  12  tag_list            196553 non-null  object
#  13  country_code        196553 non-null  object
#  14  state_code          196553 non-null  object
#  15  city                196553 non-null  object
#  16  region              196553 non-null  object
#  17  first_funding_at    196553 non-null  datetime64[ns]
#  18  last_funding_at     196553 non-null  datetime64[ns]
#  19  funding_rounds      196553 non-null  float64
#  20  funding_total_usd   196553 non-null  float64
#  21  first_milestone_at  196553 non-null  datetime64[ns]
#  22  last_milestone_at   196553 non-null  datetime64[ns]
#  23  milestones          196553 non-null  float64
#  24  relationships       196553 non-null  float64
#  25  created_by          196553 non-null  object
#  26  created_at          196553 non-null  datetime64[ns]
#  27  updated_at          196553 non-null  datetime64[ns]
#  28  lat                 196553 non-null  float64
#  29  lng                 196553 non-null  float64
#  30  ROI                 196553 non-null  float64
# dtypes: datetime64[ns](7), float64(9), object(15)
# memory usage: 46.5+ MB

# %%
for col in df.columns:
    if df[col].dtype == 'datetime64[ns]':
        df[f'{col}_Day'] = df[col].dt.day
        df[f'{col}_Month'] = df[col].dt.month
        df[f'{col}_Year'] = df[col].dt.year

# %%
df.head(10)
# Out:
#          id                           name                normalized_name  \
# 0       c:1                       Wetpaint                       wetpaint
# 1      c:10                        Flektor                        flektor
# 2     c:100                          There                          there
# 3   c:10000                        MYWEBBO                        mywebbo
# 4   c:10001             THE Movie Streamer             the movie streamer
# 5   c:10002                 Synergie Media                 synergie media
# 6   c:10003         Green Basti Ecosystems         green basti ecosystems
# 7  c:100042                       HostNine                       hostnine
# 8   c:10005              Thomas Publishing              thomas publishing
# 9  c:100062  Vetter Idea Management System  vetter idea management system
#
#                                 permalink    category_code     status  \
# 0                       /company/wetpaint              web  operating
# 1                        /company/flektor      games_video   acquired
# 2                          /company/there      games_video   acquired
# 3                        /company/mywebbo  network_hosting  operating
# 4             /company/the-movie-streamer      games_video  operating
# 5                 /company/synergie-media      advertising  operating
# 6         /company/green-basti-ecosystems        cleantech  operating
# 7                       /company/hostnine         software  operating
# 8              /company/thomas-publishing      advertising  operating
# 9  /company/vetter-idea-management-system       enterprise  operating
#
#   founded_at                domain                     homepage_url  \
# 0 2005-10-17      wetpaint-inc.com          http://wetpaint-inc.com
# 1 2005-10-17           flektor.com           http://www.flektor.com
# 2 2005-10-17             there.com             http://www.there.com
# 3 2008-07-26           mywebbo.com           http://www.mywebbo.com
# 4 2008-07-26  themoviestreamer.com      http://themoviestreamer.com
# 5 2007-06-27    synergie-media.com    http://www.synergie-media.com
# 6 2008-08-20           Unavailable                      Unavailable
# 7 2008-08-20          hostnine.com          http://www.hostnine.com
# 8 2008-08-20  thomaspublishing.com  http://www.thomaspublishing.com
# 9 2011-08-01         getvetter.com         http://www.getvetter.com
#
#    logo_width  ...  first_milestone_at_Year last_milestone_at_Day  \
# 0  401.000000  ...                     2010                    18
# 1  186.000000  ...                     2010                    18
# 2  107.000000  ...                     2003                    23
# 3  459.132685  ...                     2003                    23
# 4  200.000000  ...                     2003                    23
# 5  284.000000  ...                     2003                    23
# 6  459.132685  ...                     2003                    23
# 7  187.000000  ...                     2011                    20
# 8  276.000000  ...                     1999                     1
# 9  200.000000  ...                     2011                     1
#
#   last_milestone_at_Month last_milestone_at_Year created_at_Day  \
# 0                       9                   2013             25
# 1                       9                   2013             31
# 2                       9                   2011              6
# 3                       9                   2011             24
# 4                       9                   2011             24
# 5                       9                   2011             24
# 6                       9                   2011             24
# 7                       6                   2011              7
# 8                       6                   1999             24
# 9                       8                   2011              7
#
#   created_at_Month created_at_Year updated_at_Day updated_at_Month  \
# 0                5            2007             13                4
# 1                5            2007             23                5
# 2                8            2007              4               11
# 3                8            2008              6                9
# 4                8            2008              6                9
# 5                8            2008              6                9
# 6                8            2008             22                4
# 7                9            2011             20               12
# 8                8            2008             19               11
# 9                9            2011             24                9
#
#    updated_at_Year
# 0             2013
# 1             2008
# 2             2013
# 3             2008
# 4             2008
# 5             2008
# 6             2010
# 7             2011
# 8             2009
# 9             2011
#
# [10 rows x 52 columns]

# %%
# Stats of numeric columns
numeric_columns = ['logo_width','logo_height','funding_rounds','funding_total_usd','milestones','relationships','lat','lng','ROI']
num_col_df = df[numeric_columns]
num_col_df.describe()
# Out:
#           logo_width    logo_height  funding_rounds  funding_total_usd  \
# count  196553.000000  196553.000000   196553.000000       1.965530e+05
# mean      459.132685     222.728917        1.659760       1.481652e+07
# std       445.324843     249.307424        0.482632       2.551658e+07
# min         1.000000       1.000000        1.000000       2.910000e+02
# 25%       250.000000      97.000000        1.659760       1.481652e+07
# 50%       459.132685     222.728917        1.659760       1.481652e+07
# 75%       459.132685     222.728917        1.659760       1.481652e+07
# max     18200.000000    9600.000000       15.000000       5.700000e+09
#
#           milestones  relationships            lat            lng  \
# count  196553.000000  196553.000000  196553.000000  196553.000000
# mean        1.199402       2.852067      37.437087     -51.428830
# std         0.368905       7.391464      13.570808      62.255161
# min         1.000000       1.000000     -50.942326    -159.497746
# 25%         1.000000       1.000000      34.170561     -97.743061
# 50%         1.199402       2.852067      39.364283     -74.005973
# 75%         1.199402       2.852067      44.137870      -1.890401
# max         9.000000    1189.000000      77.553604     176.212549
#
#                  ROI
# count  196553.000000
# mean       45.745037
# std        34.741883
# min         0.011111
# 25%        45.745037
# 50%        45.745037
# 75%        45.745037
# max     13333.333333

# %%
# Identifying outliers in numeric columns and imputing them with their median value
columns_with_outliers = ['logo_width','logo_height','relationships','ROI']

for i in columns_with_outliers:
    Q1 = df[i].quantile(0.25)
    Q3 = df[i].quantile(0.75)
    IQR = Q3 - Q1
    outliers = ((df[i] < (Q1 - 1.5 * IQR)) | (df[i] > (Q3 + 1.5 * IQR)))
    median = df[i].median()
    df.loc[outliers, i] = median

# %%
# Plotting the boxplot of logo_width variable
plt.figure(figsize=(4,4))
sns.boxplot(x="logo_width",data = df)
# Out:
# <Axes: xlabel='logo_width'>

# %%
# Plotting the boxplot of logo_height variable
plt.figure(figsize=(4,4))
sns.boxplot(x="logo_height",data = df)
# Out:
# <Axes: xlabel='logo_height'>

# %%
# Plotting the boxplot of relationships variable
plt.figure(figsize=(4,4))
sns.boxplot(x="relationships",data = df)
# Out:
# <Axes: xlabel='relationships'>

# %%
# Plotting the boxplot of ROI variable
plt.figure(figsize=(4,4))
sns.boxplot(x="ROI",data = df)
# Out:
# <Axes: xlabel='ROI'>

# %%
le = LabelEncoder()
# Transforming qualitative data into quantitative data
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#    id    name  normalized_name  permalink  category_code  status founded_at  \
# 0   0  177738           188082     189098             41       3 2005-10-17
# 1   1   58822            61965      62340             12       0 2005-10-17
# 2   2  161743           170854     171780             12       0 2005-10-17
# 3   3   95656           113905     114553             25       3 2008-07-26
# 4   4  154931           169502     170425             12       3 2008-07-26
#
#    domain  homepage_url  logo_width  ...  first_milestone_at_Year  \
# 0  120718         30317  401.000000  ...                     2010
# 1   40243         62354  186.000000  ...                     2010
# 2  109492        112129  107.000000  ...                     2003
# 3   74284         86928  459.132685  ...                     2003
# 4  109272         27343  200.000000  ...                     2003
#
#    last_milestone_at_Day  last_milestone_at_Month  last_milestone_at_Year  \
# 0                     18                        9                    2013
# 1                     18                        9                    2013
# 2                     23                        9                    2011
# 3                     23                        9                    2011
# 4                     23                        9                    2011
#
#    created_at_Day  created_at_Month  created_at_Year updated_at_Day  \
# 0              25                 5             2007             13
# 1              31                 5             2007             23
# 2               6                 8             2007              4
# 3              24                 8             2008              6
# 4              24                 8             2008              6
#
#   updated_at_Month  updated_at_Year
# 0                4             2013
# 1                5             2008
# 2               11             2013
# 3                9             2008
# 4                9             2008
#
# [5 rows x 52 columns]
